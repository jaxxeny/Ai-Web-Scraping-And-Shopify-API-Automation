# %%
# automate finding a winning product on pipiads and
# adding it to shopify using python webscraping and ai automatically

# %%
# the product has to have at least 1000 like and it is using shopify in the united states
# and the product has to be running for the last month at least (30days)*
# the product has to be in the health & beauty niche

import requests

url = "https://www.pipiads.com/v3/api/product/search-page"
params = {
    "time": 30,
    "search_type": 5,
    "platform": "shopify",
    "sort": 1,
    "sort_type": "desc",
    # "category": "62739ba438365b2f72048ec9",
    "region": "US",
    "digg_count_min": 1000,
    "price_max":70,
    "current_page": 1,
    "page_size": 200
}
headers = {
    "accept": "application/json, text/plain, */*",
    "accept-language": "en-US,en;q=0.9,fr-FR;q=0.8,fr;q=0.7,ar;q=0.6",
    "access_token": "NjdiYjNkMjQ2YTFhNjE2NmQ3N2I2YjI1LTE3NDExODY0Njc=",
    "device_id": "532166263",
    "language_code": "en",
    "priority": "u=1, i",
    "sec-ch-ua": '"Not(A:Brand";v="99", "Google Chrome";v="133", "Chromium";v="133"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "time_zone_id": "Europe/Berlin",
    "timezone_offset": "-60"
}
cookies = {
    "language": "en",
    "uid": "NjdiYjNkMjQ2YTFhNjE2NmQ3N2I2YjI1LTI5MDE5Nzc0",
    "g_state": '{"i_t":1741272869255,"i_l":0}',
    "isUseScrollMode": "false_and_200",
    "PP-userInfo": '{"access_token":"NjdiYjNkMjQ2YTFhNjE2NmQ3N2I2YjI1LTE3NDExODY0Njc=","vip_deadline":1741449599,"expires":1743778467,"level":"STARTER","discount_code":null,"timezone_offset":-60,"_id":"67bb3d246a1a6166d77b6b25","time_zone_id":"Europe/Berlin","language_setting":"en","email":"jakemilleragi@gmail.com","username":"jakemilleragi@gmail.com"}'
}

response = requests.get(url, headers=headers, params=params, cookies=cookies)

(
[(x["title"],x.keys() )for x in response.json()["data"]])
# Out:
# [('10% Vitamin C Face Serum For Daily Brightness',
#   dict_keys(['id', 'title', 'image', 'price', 'currency', 'tiktok_time', 'found_time', 'latest_found_time', 'play_count', 'digg_count', 'digg_play_rate', 'comment_count', 'share_count', 'video_count', 'is_collection', 'platform', 'usd_price', 'put_days', 'ad_platform_list', 'facebook_data_count', 'facebook_digg_count', 'facebook_found_time', 'facebook_latest_found_time', 'facebook_put_days', 'all_data_count', 'all_digg_count', 'all_found_time', 'all_latest_found_time', 'all_put_days', 'all_share_count', 'facebook_share_count', 'all_comment_count', 'facebook_comment_count', 'popular_person_count', 'create_time', 'sort_id'])),
#  ('We Live Among Giants - Hoodie',
# ...

# %%
print("\n".join(f"{x["title"]} {x["id"]}" for x in response.json()["data"]))
# Out:
# 10% Vitamin C Face Serum For Daily Brightness 66b7a282a836612cd695332e
# We Live Among Giants - Hoodie 653263629b9ebe51251b90a0
# Name Wallet and Keychain Combo 6750f9c9a9e1b83a18adf786
# 1000+ Spanish Student Notes 6791dd4210dc3a0982aba6e4
# ACV Moringa For Weight Loss 66d99a21e9eee865ffbe3b43
# KEWPIE Mayonnaise, 500 g (Product of Japan) 67b3bfb93a2a0e178cbdeeb6
# PELOTAVIVA™ - Pelota de aventura interactiva para tus gatos 67b43923528721175551a736
# Hard Days - Hoodie 66ead6fc2e81f21a8fa3f6fd
# Teeth Whitening Powder - Dentist Approved 6267ca7a3a879868acae0785
# MOVA P50 Pro Ultra Robot Vacuum Coupon 67ae0313e6fe10397c0cd6c2
# FabuLove Permanent Bracelet Kit 66a59f5450f88e398368315c
# 25% AHA, 2% BHA, 5% PHA Peeling Solution for Men 66b23a903df882706bf38142
# Sunscreen Jacket - The Ultimate Sun Protection Wear 665d681134edfe605e9b2607
# Baked Balance-n-Brighten Color Correcting Foundation 6635b26c932f5b156536fe59
# OUTGLOW - Radiance Tri-Factor™ Jelly 665d6cd834edfe605e9b28fa
# ...

# %%
# get the best of them using an ai llm api , find the best product that solves a problem or has a wow factor and give me back only his id
groq_api_key = "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"
from groq import Groq
product_id = ""
client = Groq(api_key=groq_api_key)
completion = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {
                "role": "system",
                "content": "find the best product that solves a problem or has a wow factor and give me back only his id"
            },
            {
                "role": "user",
                "content": "\n".join(f"{x["title"]} {x["id"]}" for x in response.json()["data"])
            }
        ],
        temperature=1,
        # max_completion_tokens=1024,
        top_p=1,
        stream=True,
        stop=None,
    )
output = ""
for chunk in completion:
    output += chunk.choices[0].delta.content or ""
product_id = output    
print([x["title"] for x in response.json()["data"] if x["id"] == output][0],f"https://www.pipiads.com/product-search/{product_id}/")
# Out:
# 10% Vitamin C Face Serum For Daily Brightness https://www.pipiads.com/product-search/66b7a282a836612cd695332e/

# %%
# get the landing page url from pipi ads
url = "https://www.pipiads.com/v3/api/product/detail"
params = {
    "id": product_id
}
product_details_url = requests.get(url, headers=headers, params=params, cookies=cookies).json()["data"]["landing_page"].split("?")[0]
def get_final_url(initial_url):
    session = requests.Session()
    response = session.get(initial_url,headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36"}, allow_redirects=True)
    return response.url
product_details_url=get_final_url(product_details_url)+".json"

# %%
# scrape the product details name , price , images, description from the landing page
product_data = requests.get(product_details_url,headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36"}).json()["product"]
print(product_data)
name = product_data["title"]
price = product_data["variants"][0]["price"]
images =[x["src"] for x in product_data["images"]]
description = product_data["body_html"]
# Out:
# {'id': 8855910318309, 'title': '10% Vitamin C Face Serum For Daily Brightness', 'body_html': "<p><strong>Size:</strong> 30 ml | 1.01 fl. oz.</p>\n<p><strong>Suitable For:</strong> All Skin Types</p>\n<p><strong>Achieve Glowing, Brighter Skin and Reduce Dark Spots in Just 5 Days</strong></p>\n<p>Get radiant, even-toned skin with our clinically tested 10% Vitamin C Face Serum, specially designed to target dark spots, uneven skin tone, and dullness. This powerful formula works effectively to reveal glowing, brighter skin in as little as 5 days. \xa0</p>\n<p><strong>Why Choose Our 10% Vitamin C Face Serum?</strong><br>• Fights Dark Spots: Packed with a stable form of Vitamin C (3-O-Ethyl Ascorbic Acid), this serum reduces dark spots and promotes an even skin tone. \xa0<br>• Brightens and Evens Out Skin: Say goodbye to dullness as this formula enhances your skin’s natural glow and smooths uneven skin texture. \xa0<br>• Enriched with Australian Kakadu Plum: One of the richest sources of Vi
# ...

# %%
# connect to shopify api
ACCESS_TOKEN = "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"
API_KEY = "1f3a99732fb81beb94d44b77222da04b"
API_SECRET = "75391ad0eb8426741edc737491ddf8c8"

# upload the name,description,images,price of the product make sure to remove the branding name of the product
import shopify




SHOP_NAME = "quickstart-9d299818"


shop_url = f"https://{API_KEY}:{ACCESS_TOKEN}@{SHOP_NAME}.myshopify.com/admin/api/2023-01"
shopify.ShopifyResource.set_site(shop_url)


new_product = shopify.Product()
new_product.title = name
new_product.body_html = description
new_product.vendor = "Jaxxen"
# new_product.product_type = "T-Shirts"

new_product.images = [{"src": img} for img in images]


variant = shopify.Variant()
variant.price = price
# variant.sku = "JAXXEN-001"
# variant.inventory_management = "shopify"
# variant.inventory_quantity = 10

# Assign the variant to the product
new_product.variants = [variant]

# Save the product to Shopify
if new_product.save():
    print(f"Product '{new_product.title}' uploaded successfully!")
else:
    print("Error uploading product:", new_product.errors.full_messages())
# Out:
# Product '10% Vitamin C Face Serum For Daily Brightness' uploaded successfully!
